# %% [markdown]
# # Overview
#
# This notebook assumes you have already collected and scored MOC tweets. It creates a dataset for use in R to analyze the patterns of polarization over time. You will do some parsing on an AWS server and some locally before ultimately making a CSV file that you can open and analyze in R.
#
# LH Note: on my computer, Git stuff and data live in different places, so you'll see notes about moving files or changing directories. I haven't figured out a good way to keep files in both places or to mirror or sync or whatever. So, for now, paths are hard-coded or there's a note about where to find a file.

# %% [markdown]
# ## Setup and Helpers

# %%
# Based on https://stackoverflow.com/questions/26415906/read-multiple-txt-files-into-pandas-dataframe-with-filename-as-column-header
import pandas as pd
import os
import glob
import yaml
import numpy as np

def build_file_list(directory, extension):
    '''
    args: 
        directory - full path to where the files are
            ex: /data/purpletag/scores
        extension - tells us which files to include in the list
            ex: *.l.moc.scores # using 1-day purpletag MOC scores
    '''
    
    # Step 1: get a list of all score files in target directory
    fileList = []
    os.chdir( directory )

    # Step 2: Build up list of files:
    for files in glob.glob(extension): 
        fileName, fileExtension = os.path.splitext(files)
        fileList.append(files) #filename with extension
        
    return fileList

def build_df(fileList, outfile, score_type):
    '''
    args:
        fileList - list of files to include, usually output from build_file_list
        outfile - full path to where to put the df
            ex: /data/purpletag/mocs_by_date.pkl
    '''
    # Step 3: Build up DataFrame:
    # Based on https://stackoverflow.com/questions/35717706/python-how-to-turn-a-dictionary-of-dataframes-into-one-big-dataframe-with-colum
    d = {} # dictionary to hold multiple dfs

    for filename in fileList:
        df1 = pd.read_csv(filename, header=None, sep=' ', index_col=0)
        if score_type == 'moc': # moc score files
            d[filename[:-13]] = df1
        else: # tag score files
            d[filename[:-9]] = df1

    df = pd.concat(d, axis=1)
    df.columns = df.columns.droplevel(-1) 

    df.to_pickle(outfile)

# %%
# set some variables that get used a few times below
#git_path = "/home/ubuntu/purpletag" # where is the GitHub repo that holds this notebook
git_path = "/Users/libbyh/Documents/git/libbyh/purpletag/"
git_data_path = git_path + "2016-election-study/data-files/"
pt_path = "/data/purpletag" # where are the scores and other purpletag-generated data

# %%
fileList = build_file_list('/data/purpletag/scores', '*.1.moc.scores')
build_df(fileList, '/data/purpletag/mocs_by_date_test.pkl', 'moc')

# %%
# Thank you, Roger Allen, https://gist.github.com/rogerallen/1583593
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}

# %% [markdown]
# # Get Data
#
# 2016 election data is on an AWS server under ```/data/purpletag```.
#
# To login:
#
# ```ssh -i ~/.ssh/carolgrrr.pem ubuntu@purpletag.casmlab.org```
#
# The data is large (> 4GB), so best to run Juypter notebooks to parse on the server. Then CSV files can be used locally.
#
# You can run a notebook on the server and use your local browser with these two commands:
#
# * ```ssh -L 8080:localhost:8888 -i ~/.ssh/carolgrrr.pem ubuntu@purpletag.casmlab.org```
# * ```nohup jupyter notebook --no-browser > log.txt 2>&1 &```
#
# Then access ```http://localhost:8080``` in your browser.

# %% [markdown]
# ## On server: Parsing from ```scores``` files to CSV
#
# This section assumes you have already run purpletag's ```collect``` and ```score``` functions and gotten the Twitter data that you want in JSON format and parsed that data into score files.

# %% [markdown]
# Move the file from the AWS server to local if you want to work locally. For example, to move the file ```mocs_by_date.pkl``` from the server to my local repo, I use:
#
# ```scp -i ~/.ssh/carolgrrr.pem ubuntu@purpletag.casmlab.org:/data/purpletag/mocs_by_date.pkl ~/Documents/git/casmlab/purpletag/files/```

# %% [markdown]
# ## Locally: Prepping for stats

# %% [markdown]
# We now have a pickled dataframe of the form handleXdate. We need to keep data only from Labor Day to Election Day and get weekly averages.

# %%
import pandas as pd

df = pd.read_pickle(git_data_path + 'mocs_by_date.pkl')
df.head()
# Out:
#                  2015-11-10  2015-11-11  2015-11-12  2015-11-13  2015-11-14  \
# austinscottga08         NaN     2.40933         NaN         NaN         NaN
# benniegthompson         NaN         NaN         NaN         NaN         NaN
# bettymccollum04         NaN         NaN         NaN         NaN         NaN
# billpascrell            NaN         NaN   -1.168750   -0.916501   -0.972477
# boblatta                NaN         NaN    0.100723         NaN         NaN
#
#                  2015-11-15  2015-11-16  2015-11-17  2015-11-18  2015-11-19  \
# austinscottga08         NaN         NaN         NaN         NaN         NaN
# benniegthompson         NaN         NaN     3.85585         NaN         NaN
# bettymccollum04         NaN         NaN         NaN         NaN         NaN
# billpascrell            NaN         NaN         NaN         NaN         NaN
# boblatta            1.70286         NaN     1.56897         NaN   -0.031978
#
#                     ...      2016-10-30  2016-10-31  2016-11-01  2016-11-02  \
# austinscottga08     ...             NaN         NaN         NaN         NaN
# benniegthompson     ...             NaN         NaN         NaN         NaN
# bettymccollum04     ...             NaN         NaN     -90.838    -61.3435
# billpascrell        ...             NaN         NaN         NaN    -17.9542
# boblatta            ...             NaN         NaN         NaN         NaN
#
#                  2016-11-03  2016-11-04  2016-11-05  2016-11-06  2016-11-07  \
# austinscottga08         NaN         NaN         NaN         NaN         NaN
# benniegthompson         NaN         NaN         NaN         NaN         NaN
# bettymccollum04     -40.482         NaN    -33.4513         NaN         NaN
# billpascrell            NaN         NaN         NaN         NaN         NaN
# boblatta                NaN         NaN         NaN         NaN         NaN
#
#                  2016-11-08
# austinscottga08         NaN
# benniegthompson         NaN
# bettymccollum04         NaN
# billpascrell            NaN
# boblatta                NaN
#
# [5 rows x 365 columns]

# %%
def weekly_avg(df):
    '''
    Given a df from build_df, keep just the weeks we are interested in.
    '''
    week1_dates = ['2016-09-06','2016-09-07','2016-09-08','2016-09-09','2016-09-10','2016-09-11','2016-09-12']
    week2_dates = ['2016-09-13','2016-09-14','2016-09-15','2016-09-16','2016-09-17','2016-09-18','2016-09-19']
    week3_dates = ['2016-09-20','2016-09-21','2016-09-22','2016-09-23','2016-09-24','2016-09-25','2016-09-26']
    week4_dates = ['2016-09-27','2016-09-28','2016-09-29','2016-09-30','2016-10-01','2016-10-02','2016-10-03']
    week5_dates = ['2016-10-04','2016-10-05','2016-10-06','2016-10-07','2016-10-08','2016-10-09','2016-10-10']
    week6_dates = ['2016-10-11','2016-10-12','2016-10-13','2016-10-14','2016-10-15','2016-10-16','2016-10-17']
    week7_dates = ['2016-10-18','2016-10-19','2016-10-20','2016-10-21','2016-10-22','2016-10-23','2016-10-24']
    week8_dates = ['2016-10-25','2016-10-26','2016-10-27','2016-10-28','2016-10-29','2016-10-30','2016-10-31']
    week9_dates = ['2016-11-01','2016-11-02','2016-11-03','2016-11-04','2016-11-05','2016-11-06','2016-11-07']

    df['week1'] = df[week1_dates].mean(axis=1)
    df['week2'] = df[week2_dates].mean(axis=1)
    df['week3'] = df[week3_dates].mean(axis=1)
    df['week4'] = df[week4_dates].mean(axis=1)
    df['week5'] = df[week5_dates].mean(axis=1)
    df['week6'] = df[week6_dates].mean(axis=1)
    df['week7'] = df[week7_dates].mean(axis=1)
    df['week8'] = df[week8_dates].mean(axis=1)
    df['week9'] = df[week9_dates].mean(axis=1)
    
    return df

df = weekly_avg(df)
df.head()
# Out:
#                  2015-11-10  2015-11-11  2015-11-12  2015-11-13  2015-11-14  \
# austinscottga08         NaN     2.40933         NaN         NaN         NaN
# benniegthompson         NaN         NaN         NaN         NaN         NaN
# bettymccollum04         NaN         NaN         NaN         NaN         NaN
# billpascrell            NaN         NaN   -1.168750   -0.916501   -0.972477
# boblatta                NaN         NaN    0.100723         NaN         NaN
#
#                  2015-11-15  2015-11-16  2015-11-17  2015-11-18  2015-11-19  \
# austinscottga08         NaN         NaN         NaN         NaN         NaN
# benniegthompson         NaN         NaN     3.85585         NaN         NaN
# bettymccollum04         NaN         NaN         NaN         NaN         NaN
# billpascrell            NaN         NaN         NaN         NaN         NaN
# boblatta            1.70286         NaN     1.56897         NaN   -0.031978
#
#                   ...     2016-11-08      week1       week2      week3  \
# austinscottga08   ...            NaN        NaN    4.932035        NaN
# benniegthompson   ...            NaN        NaN   -1.211380        NaN
# bettymccollum04   ...            NaN -56.669016 -119.884760 -67.172900
# billpascrell      ...            NaN  -2.871430   -2.623810  -2.353348
# boblatta          ...            NaN   1.379970    9.673527        NaN
#
#                      week4      week5      week6     week7      week8    week9
# austinscottga08   1.064290   3.675700   6.042600  1.561610        NaN      NaN
# benniegthompson        NaN        NaN  -1.823010       NaN        NaN      NaN
# bettymccollum04 -59.540265 -27.995798 -33.955595 -4.879673 -33.080633 -56.5287
# billpascrell     -2.337897        NaN  -1.026550       NaN  -1.333330 -17.9542
# boblatta               NaN        NaN   0.974138       NaN        NaN      NaN
#
# [5 rows x 374 columns]

# %%
weekly_df = df[['week1','week2','week3','week4','week5','week6','week7','week8','week9']]
weekly_df["handle"] = weekly_df.index.str.lower() # this line throws the SettingWithCopyWarning which I'm ignoring
weekly_df.to_csv(git_data_path + 'week_by_handle.csv', encoding='utf-8')
weekly_df
# Out:
# /Users/libbyh/anaconda/envs/purpletag/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                      week1       week2      week3      week4      week5  \
# austinscottga08        NaN    4.932035        NaN   1.064290   3.675700
# benniegthompson        NaN   -1.211380        NaN        NaN        NaN
# bettymccollum04 -56.669016 -119.884760 -67.172900 -59.540265 -27.995798
# billpascrell     -2.871430   -2.623810  -2.353348  -2.337897        NaN
# boblatta          1.379970    9.673527        NaN        NaN        NaN
# bradsherman            NaN   -1.941180        NaN  -5.381950        NaN
# call_me_dutch    -1.312583   -4.765343  -3.129013  -1.573270  -2.967365
# candicemiller     1.678195         NaN   0.029657  -0.969076        NaN
# cathymcmorris     7.926215    3.141282   8.873570  13.830632   1.000000
# cbrangel        -39.434357  -61.711175 -41.164824 -37.333904 -19.490345
# chelliepingree   -0.478424   -1.141239   0.001002  -3.231895  -0.645854
# chrismurphyct   -10.588038  -42.525738  -4.712589  -4.560957  -6.453698
# chrisvanhollen  -54.966055  -99.947165 -10.479500        NaN -13.279100
# chuckgrassley          NaN    0.688525   1.228070   1.193205   0.906780
# clyburn          -0.957143 -125.927880 -19.132180 -49.990600        NaN
# conawaytx11            NaN         NaN        NaN        NaN        NaN
# congbillposey     0.967105         NaN        NaN        NaN        NaN
# congculberson     2.049355   16.449665        NaN   5.953135   0.906780
# conghuelskamp     3.189410    5.334424   9.784920  12.915598  10.034006
# congmikesimpson   1.694790    0.757014   1.076198   1.064290   2.427180
# congpalazzo       2.779320         NaN  -1.052340  16.833300        NaN
# congressmangt     5.996984   12.966840   8.609298   6.305415   5.557500
# congressmanhice   5.782418   22.958759   3.558067   2.783482   2.340362
# congressmanruiz  -0.619814         NaN        NaN  -2.495040  -0.966387
# corybooker      -45.880645   -4.211167 -10.528431  -9.191768  -4.854678
# cynthialummis     0.941390         NaN  -0.000332        NaN   1.699210
# darrellissa            NaN    6.615326   1.780650        NaN        NaN
# daveloebsack      1.379970    1.141780  -1.222368  -4.729487        NaN
# davereichert      1.749340    9.632034   4.175330   2.660523   4.601563
# desjarlaistn04    2.008113    6.360580   2.063235        NaN   1.675186
# ...                    ...         ...        ...        ...        ...
# sentomcotton      9.259097   18.984000   5.861856   2.213970   2.213375
# sentoomey         0.450846    1.340321        NaN   1.730260        NaN
# senwarren       -16.472357  -20.003685        NaN  -9.442620        NaN
# senwhitehouse   -26.853336  -27.274468  -5.569098  -6.160863  -2.246048
# speakerryan      10.366340   37.134494  20.404184  24.263986  18.337240
# staceyplaskett  -74.466400  -64.339300 -21.400700  -3.613390 -14.520628
# stevedaines       0.614514   15.955496   3.194646   2.988327   1.992373
# stevekingia       0.884615         NaN        NaN   1.058930        NaN
# steveknight25    -0.033462         NaN        NaN   0.129049        NaN
# stevescalise     12.777685   17.993253  11.207510  11.448580  12.882075
# susanwbrooks     -1.859935   20.762442   3.977370   2.799142   0.906780
# teammoulton     -10.223317  -39.223645  -9.080928  -6.886165 -14.323355
# tgowdysc          1.379970   24.362623   5.717880   6.417177        NaN
# toddrokita        3.874347    6.490850   2.564010  17.983067   3.175610
# tomcoleok04      -0.927027    1.490305   0.890323        NaN        NaN
# tomrooney              NaN    0.916522        NaN        NaN        NaN
# tulsipress       -5.130997   -9.110062  -4.423757 -10.482710  -4.345324
# txrandy14         2.778870    2.538835   2.618932   6.070819        NaN
# usrepdavidjolly  -8.071250   -7.510378        NaN   1.077513   1.843037
# usrepgarypalmer  -0.602145    4.222761   1.906190  11.043693   1.240658
# usrepkcastor    -44.156545  -44.457523 -45.454540  -6.229427 -30.346366
# usrepkeating     -2.224717    0.067697  -0.905202        NaN  -0.967118
# usreplong        18.216237   21.992478  14.218810  24.450705   9.235695
# usrepmikedoyle         NaN -142.917000  -1.560995        NaN        NaN
# usreprhinojosa   -4.539970   -2.240295  -5.791910 -28.127240        NaN
# usrepricknolan  -39.178265   -1.156808  -1.441080   5.811510        NaN
# usreprodney       1.909774    2.800560   1.726958   2.721420   0.901988
# vernbuchanan      0.426322    0.691403   0.570157  -0.001153   0.647187
# virginiafoxx      1.934210    7.636600   5.090665  15.156971   1.016810
# whiphoyer       -53.894808  -96.180740 -60.315710 -57.365228 -28.156915
#
#                      week6      week7      week8      week9           handle
# austinscottga08   6.042600   1.561610        NaN        NaN  austinscottga08
# benniegthompson  -1.823010        NaN        NaN        NaN  benniegthompson
# bettymccollum04 -33.955595  -4.879673 -33.080633 -56.528700  bettymccollum04
# billpascrell     -1.026550        NaN  -1.333330 -17.954200     billpascrell
# boblatta          0.974138        NaN        NaN        NaN         boblatta
# bradsherman            NaN        NaN        NaN  -0.748092      bradsherman
# call_me_dutch    -2.715476 -20.466664  -1.576630  -6.732820    call_me_dutch
# candicemiller     1.086960        NaN        NaN        NaN    candicemiller
# cathymcmorris     7.823813   3.747878  11.442992  10.554400    cathymcmorris
# cbrangel        -32.642642  -8.514975  -4.536950 -18.458800         cbrangel
# chelliepingree  -42.315341  -0.901049  -0.552993  -0.143404   chelliepingree
# chrismurphyct   -18.425498 -17.709142  -4.559876 -19.230898    chrismurphyct
# chrisvanhollen   -3.836070  -0.720238        NaN        NaN   chrisvanhollen
# chuckgrassley     3.187672   0.983485   0.796748   1.163210    chuckgrassley
# clyburn         -36.460200  -2.107520 -11.323005        NaN          clyburn
# conawaytx11            NaN        NaN        NaN        NaN      conawaytx11
# congbillposey          NaN        NaN        NaN        NaN    congbillposey
# congculberson     3.147655   1.953250  13.038500   9.486985    congculberson
# conghuelskamp     3.440394   8.912740  16.605708   7.408762    conghuelskamp
# congmikesimpson        NaN   0.989362   0.832990        NaN  congmikesimpson
# congpalazzo       0.909836   0.989362   1.107093        NaN      congpalazzo
# congressmangt     5.305560   6.935355   3.846574   5.328350    congressmangt
# congressmanhice   4.256890   4.937345   6.701863  -1.357910  congressmanhice
# congressmanruiz        NaN        NaN  -1.173910        NaN  congressmanruiz
# corybooker       -8.239361  -3.661115  -4.371392  -5.539673       corybooker
# cynthialummis     6.582540   2.968090        NaN   6.298080    cynthialummis
# darrellissa            NaN        NaN   0.421653   1.259130      darrellissa
# daveloebsack           NaN        NaN        NaN   0.245202     daveloebsack
# davereichert      1.999003   3.281393   1.743487   8.209250     davereichert
# desjarlaistn04    9.519139   3.868577   9.979917   8.367273   desjarlaistn04
# ...                    ...        ...        ...        ...              ...
# sentomcotton      5.598002   2.063882  17.383783  11.070462     sentomcotton
# sentoomey         5.793066   0.989362  19.260000   2.122601        sentoomey
# senwarren              NaN  -2.296465        NaN        NaN        senwarren
# senwhitehouse    -9.130128  -4.165760  -5.475702  -2.099844    senwhitehouse
# speakerryan      20.073905  23.951600  34.366250  31.173480      speakerryan
# staceyplaskett         NaN        NaN        NaN -45.344993   staceyplaskett
# stevedaines       1.186965   2.741240        NaN   3.044650      stevedaines
# stevekingia      -1.223405        NaN        NaN        NaN      stevekingia
# steveknight25          NaN   0.989362        NaN        NaN    steveknight25
# stevescalise     13.842550  10.187033  22.833387  20.397701     stevescalise
# susanwbrooks      6.771700   4.094890        NaN  11.751523     susanwbrooks
# teammoulton     -49.923771  -2.670388  -2.155590  -4.560592      teammoulton
# tgowdysc               NaN        NaN   1.352780   1.464236         tgowdysc
# toddrokita        0.650268        NaN   1.266680   5.306392       toddrokita
# tomcoleok04            NaN   1.978720        NaN   1.159570      tomcoleok04
# tomrooney              NaN        NaN        NaN        NaN        tomrooney
# tulsipress       -3.328350  -3.043788  -6.610294  -5.650186       tulsipress
# txrandy14         1.541873        NaN   2.607690   3.478720        txrandy14
# usrepdavidjolly   4.153915   1.680930   0.673365   1.021028  usrepdavidjolly
# usrepgarypalmer   1.393615   1.058250  19.409600   2.088293  usrepgarypalmer
# usrepkcastor    -27.690219 -17.485778 -39.017744 -32.601153     usrepkcastor
# usrepkeating     -4.396400  -0.848739  -2.219450  -0.748092     usrepkeating
# usreplong         6.765670   1.778839  21.627383  27.179025        usreplong
# usrepmikedoyle         NaN  -1.010750        NaN  -7.221050   usrepmikedoyle
# usreprhinojosa         NaN        NaN  -1.096150        NaN   usreprhinojosa
# usrepricknolan         NaN   0.514431        NaN   0.010980   usrepricknolan
# usreprodney       1.016199   1.846980   0.805326  10.328444      usreprodney
# vernbuchanan      1.097090   1.097957   0.838044   0.908607     vernbuchanan
# virginiafoxx           NaN        NaN   3.649120        NaN     virginiafoxx
# whiphoyer       -65.737750 -36.006767 -48.123075 -64.218600        whiphoyer
#
# [511 rows x 10 columns]

# %%
weekly_df.sort_values(by = 'week2', ascending = True).head()
# Out:
#                   week1    week2      week3      week4     week5      week6  \
# replawrence  -28.383236 -308.088 -18.402877 -32.248687  0.698665 -43.500575
# repdennyheck        NaN -300.145 -10.527903 -17.045025       NaN -18.147370
# repbobbyrush        NaN -270.786 -30.679700  -1.161955       NaN        NaN
# nitalowey     -1.298840 -215.463 -39.049700  -6.699170       NaN -11.493604
# repcleaver    -6.302088 -194.110  -8.202654 -32.020135 -0.119293   0.375556
#
#                   week7      week8      week9        handle
# replawrence         NaN        NaN  -0.811634   replawrence
# repdennyheck -16.686711 -40.557700 -62.144650  repdennyheck
# repbobbyrush        NaN  -8.652900  -1.898720  repbobbyrush
# nitalowey     -1.084320  -3.043239 -18.510867     nitalowey
# repcleaver   -18.248317  -3.684110  -9.614692    repcleaver

# %% [markdown]
# ## Merge with legislator data
# ### Legislator Meta Data
# Now we merge our #polar-tag data with data about the legislators (e.g., party, state).

# %%
# get term info 
# https://stackoverflow.com/questions/35968189/retrieving-data-from-a-yaml-file-based-on-a-python-list

# Connect to data from Govtrack Nov 15, 2016 commit
# https://github.com/unitedstates/congress-legislators/tree/1473ea983d5538c25f5d315626445ab038d8141b
with open(git_data_path + 'legislators-social-media-nov16.yaml', 'r') as f:
    df_social = pd.io.json.json_normalize(yaml.load(f))

with open(git_data_path + 'legislators-current-nov16.yaml', 'r') as f:
    df_current = pd.io.json.json_normalize(yaml.load(f), 'terms', [['id','bioguide'],['name','last']])

df_current_term = df_current.loc[df_current['end'] > '2016-01-01'] 
df_current_term = df_current_term[['district','state','party','type','id.bioguide','name.last']]

# merge everything into one data frame with one row per MOC
df_meta = pd.merge(df_current_term, df_social, on="id.bioguide")

df_meta["handle"] = df_meta["social.twitter"].str.lower()
df_meta['district'] = np.where(df_meta['type'] == 'sen', 'None', df_meta['district'])

df_meta = df_meta[['id.bioguide','handle','state','district','type','party','name.last']]

df_meta.to_csv(git_data_path + 'legislator_meta.csv', encoding='utf-8')

df_meta
# Out:
#     id.bioguide           handle state district type        party   name.last
# 0       B000944  sensherrodbrown    OH     None  sen     Democrat       Brown
# 1       C000127  senatorcantwell    WA     None  sen     Democrat    Cantwell
# 2       C000141    senatorcardin    MD     None  sen     Democrat      Cardin
# 3       C000174    senatorcarper    DE     None  sen     Democrat      Carper
# 4       C001070      senbobcasey    PA     None  sen     Democrat       Casey
# 5       C001071     senbobcorker    TN     None  sen   Republican      Corker
# 6       F000062     senfeinstein    CA     None  sen     Democrat   Feinstein
# 7       H000338    senorrinhatch    UT     None  sen   Republican       Hatch
# 8       K000367              NaN    MN     None  sen     Democrat   Klobuchar
# 9       M001170  mccaskilloffice    MO     None  sen     Democrat   McCaskill
# 10      M000639  senatormenendez    NJ     None  sen     Democrat    Menéndez
# 11      N000032    senbillnelson    FL     None  sen     Democrat      Nelson
# 12      S000033       sensanders    VT     None  sen  Independent     Sanders
# 13      S000770      senstabenow    MI     None  sen     Democrat    Stabenow
# 14      T000464    senatortester    MT     None  sen     Democrat      Tester
# 15      W000802    senwhitehouse    RI     None  sen     Democrat  Whitehouse
# 16      B001261  senjohnbarrasso    WY     None  sen   Republican    Barrasso
# 17      W000437    senatorwicker    MS     None  sen   Republican      Wicker
# 18      A000360     senalexander    TN     None  sen   Republican   Alexander
# 19      C000567   senthadcochran    MS     None  sen   Republican     Cochran
# 20      C001035   senatorcollins    ME     None  sen   Republican     Collins
# 21      C001056       johncornyn    TX     None  sen   Republican      Cornyn
# 22      D000563    senatordurbin    IL     None  sen     Democrat      Durbin
# 23      E000285      senatorenzi    WY     None  sen   Republican        Enzi
# 24      G000359       grahamblog    SC     None  sen   Republican      Graham
# 25      I000024      inhofepress    OK     None  sen   Republican      Inhofe
# 26      M000355   mcconnellpress    KY     None  sen   Republican   McConnell
# 27      M001176   senjeffmerkley    OR     None  sen     Democrat     Merkley
# 28      R000122      senjackreed    RI     None  sen     Democrat        Reed
# 29      R000584     senatorrisch    ID     None  sen   Republican       Risch
# ..          ...              ...   ...      ...  ...          ...         ...
# 506     H001070         rephardy    NV      4.0  rep   Republican       Hardy
# 507     Z000017     repleezeldin    NY      1.0  rep   Republican      Zeldin
# 508     R000602  repkathleenrice    NY      4.0  rep     Democrat        Rice
# 509     S001196      repstefanik    NY     21.0  rep   Republican    Stefanik
# 510     K000386     repjohnkatko    NY     24.0  rep   Republican       Katko
# 511     R000604       reprussell    OK      5.0  rep   Republican     Russell
# 512     C001106  repryancostello    PA      6.0  rep   Republican    Costello
# 513     B001296  repbrendanboyle    PA     13.0  rep     Democrat       Boyle
# 514     R000601     repratcliffe    TX      4.0  rep   Republican   Ratcliffe
# 515     H001073    hurdonthehill    TX     23.0  rep   Republican        Hurd
# 516     B001291    repbrianbabin    TX     36.0  rep   Republican       Babin
# 517     L000584       repmialove    UT      4.0  rep   Republican        Love
# 518     B001292      repdonbeyer    VA      8.0  rep     Democrat       Beyer
# 519     C001105      repcomstock    VA     10.0  rep   Republican    Comstock
# 520     P000610   staceyplaskett    VI      0.0  rep     Democrat    Plaskett
# 521     N000189      repnewhouse    WA      4.0  rep   Republican    Newhouse
# 522     G000576      repgrothman    WI      6.0  rep   Republican    Grothman
# 523     M001195    repalexmooney    WV      2.0  rep   Republican      Mooney
# 524     J000297   repevanjenkins    WV      3.0  rep   Republican     Jenkins
# 525     R000600         repamata    AS      0.0  rep   Republican       Amata
# 526     S001198   sendansullivan    AK     None  sen   Republican    Sullivan
# 527     P000612   sendavidperdue    GA     None  sen   Republican      Perdue
# 528     E000295     senjoniernst    IA     None  sen   Republican       Ernst
# 529     T000476    senthomtillis    NC     None  sen   Republican      Tillis
# 530     R000605    senatorrounds    SD     None  sen   Republican      Rounds
# 531     W000819    repmarkwalker    NC      6.0  rep   Republican      Walker
# 532     S001197         sensasse    NE     None  sen   Republican       Sasse
# 533     D000625    repdandonovan    NY     11.0  rep   Republican     Donovan
# 534     K000388    reptrentkelly    MS      1.0  rep   Republican       Kelly
# 535     L000585        replahood    IL     18.0  rep   Republican      LaHood
#
# [536 rows x 7 columns]

# %% [markdown]
# ### 2016 Election Results
# Now add the results from the election

# %%
# get Ballotpedia House results data
bp_house = pd.read_csv(git_data_path + 'house_results.csv', sep=",", header=0, thousands=',')
bp_house['state_district'] = bp_house.index
bp_house['state'], bp_house['district'] = bp_house['district'].str.split('-',1).str
bp_house['district'] = bp_house['district'].str.replace('AL','0')
bp_house['district'] = bp_house['district'].astype(float).astype(str)
bp_house = bp_house[['state','district','inc_name','inc_party','inc_ran','inc_won','had_challenger','winner_votes','runnerup_votes','winner_party','runnerup_party']]
bp_house.head()
# Out:
#   state district        inc_name inc_party  inc_ran  inc_won  had_challenger  \
# 0    AK      0.0      Young, Don         R        1        1               1
# 1    AL      1.0  Byrne, Bradley         R        1        1               0
# 2    AL      2.0    Roby, Martha         R        1        1               1
# 3    AL      3.0    Rogers, Mike         R        1        1               1
# 4    AL      4.0   Aderholt, Rob         R        1        1               0
#
#    winner_votes  runnerup_votes winner_party runnerup_party
# 0      155088.0        111019.0            R              D
# 1      208083.0          7810.0            R       write in
# 2      134886.0        112089.0            R              D
# 3      192164.0         94549.0            R              D
# 4      235925.0          3519.0            R       write in

# %%
# get Ballotpedia Senate results data
bp_sen = pd.read_csv(git_data_path + 'senate_results.csv', sep=",", header=0, thousands=',')
bp_sen['district'] = 'None'
bp_sen = bp_sen[['state','district','inc_name','inc_party','inc_ran','inc_won','had_challenger','winner_votes','runnerup_votes','winner_party','runnerup_party']]
bp_sen.head()
# Out:
#   state district   inc_name inc_party  inc_ran  inc_won  had_challenger  \
# 0    AL     None     Shelby         R        1        1               1
# 1    AK     None  Murkowski         R        1        1               1
# 2    AZ     None     McCain         R        1        1               1
# 3    AR     None    Boozman         R        1        1               1
# 4    CA     None      Boxer         D        0        0               0
#
#    winner_votes  runnerup_votes winner_party runnerup_party
# 0       1335104          748709            R              D
# 1        138149           36200            R              D
# 2       1359267         1031245            R              D
# 3        661984          400602            R              D
# 4       7542753         4701417            D              D

# %%
# match bioguide id data to name data from Ballotpedia for the House
house_election_and_meta = pd.merge(df_meta, bp_house, on=['state','district'], how='right')
house_election_and_meta
# Out:
#     id.bioguide           handle state district type       party  \
# 0       A000055  robert_aderholt    AL      4.0  rep  Republican
# 1       A000367              NaN    MI      3.0  rep  Republican
# 2       B001269   reploubarletta    PA     11.0  rep  Republican
# 3       B000213     repjoebarton    TX      6.0  rep  Republican
# 4       B001270     repkarenbass    CA     37.0  rep    Democrat
# 5       B000287       repbecerra    CA     34.0  rep    Democrat
# 6       B001271   congressmandan    MI      1.0  rep  Republican
# 7       B001257  repgusbilirakis    FL     12.0  rep  Republican
# 8       B001250     reprobbishop    UT      1.0  rep  Republican
# 9       B000490    sanfordbishop    GA      2.0  rep    Democrat
# 10      B001273    repdianeblack    TN      6.0  rep  Republican
# 11      B001243  marshablackburn    TN      7.0  rep  Republican
# 12      B000574  blumenauermedia    OR      3.0  rep    Democrat
# 13      B001255      repboustany    LA      3.0  rep  Republican
# 14      B000755    repkevinbrady    TX      8.0  rep  Republican
# 15      B001227         repbrady    PA      1.0  rep    Democrat
# 16      B001274      repmobrooks    AL      5.0  rep  Republican
# 17      B000911  repcorrinebrown    FL      5.0  rep    Democrat
# 18      B001260     vernbuchanan    FL     16.0  rep  Republican
# 19      B001275  replarrybucshon    IN      8.0  rep  Republican
# 20      B001248  michaelcburgess    TX     26.0  rep  Republican
# 21      B001251    gkbutterfield    NC      1.0  rep    Democrat
# 22      C000059       kencalvert    CA     42.0  rep  Republican
# 23      C001036     reploiscapps    CA     24.0  rep    Democrat
# 24      C001037   repmikecapuano    MA      7.0  rep    Democrat
# 25      C001083     johncarneyde    DE      0.0  rep    Democrat
# 26      C001072   repandrecarson    IN      7.0  rep    Democrat
# 27      C001051      judgecarter    TX     31.0  rep  Republican
# 28      C001066     usrepkcastor    FL     14.0  rep    Democrat
# 29      C000266   repstevechabot    OH      1.0  rep  Republican
# ..          ...              ...   ...      ...  ...         ...
# 405     A000373   repbradashford    NE      2.0  rep    Democrat
# 406     M001193  reptommacarthur    NJ      3.0  rep  Republican
# 407     W000822        repbonnie    NJ     12.0  rep    Democrat
# 408     H001070         rephardy    NV      4.0  rep  Republican
# 409     Z000017     repleezeldin    NY      1.0  rep  Republican
# 410     R000602  repkathleenrice    NY      4.0  rep    Democrat
# 411     S001196      repstefanik    NY     21.0  rep  Republican
# 412     K000386     repjohnkatko    NY     24.0  rep  Republican
# 413     R000604       reprussell    OK      5.0  rep  Republican
# 414     C001106  repryancostello    PA      6.0  rep  Republican
# 415     B001296  repbrendanboyle    PA     13.0  rep    Democrat
# 416     R000601     repratcliffe    TX      4.0  rep  Republican
# 417     H001073    hurdonthehill    TX     23.0  rep  Republican
# 418     B001291    repbrianbabin    TX     36.0  rep  Republican
# 419     L000584       repmialove    UT      4.0  rep  Republican
# 420     B001292      repdonbeyer    VA      8.0  rep    Democrat
# 421     C001105      repcomstock    VA     10.0  rep  Republican
# 422     N000189      repnewhouse    WA      4.0  rep  Republican
# 423     G000576      repgrothman    WI      6.0  rep  Republican
# 424     M001195    repalexmooney    WV      2.0  rep  Republican
# 425     J000297   repevanjenkins    WV      3.0  rep  Republican
# 426     W000819    repmarkwalker    NC      6.0  rep  Republican
# 427     D000625    repdandonovan    NY     11.0  rep  Republican
# 428     K000388    reptrentkelly    MS      1.0  rep  Republican
# 429     L000585        replahood    IL     18.0  rep  Republican
# 430         NaN              NaN    HI      1.0  NaN         NaN
# 431         NaN              NaN    KY      1.0  NaN         NaN
# 432         NaN              NaN    MN      7.0  NaN         NaN
# 433         NaN              NaN    OH      8.0  NaN         NaN
# 434         NaN              NaN    PA      2.0  NaN         NaN
#
#           name.last                inc_name inc_party  inc_ran  inc_won  \
# 0          Aderholt           Aderholt, Rob         R        1        1
# 1             Amash           Amash, Justin         R        1        1
# 2          Barletta           Barletta, Lou         R        1        1
# 3            Barton             Barton, Joe         R        1        1
# 4              Bass             Bass, Karen         D        1        1
# 5           Becerra         Becerra, Xavier         D        1        1
# 6          Benishek           Bergman, Jack         R        0        0
# 7         Bilirakis          Bilirakis, Gus         R        1        1
# 8            Bishop             Bishop, Rob         R        1        1
# 9            Bishop         Bishop, Sanford         D        1        1
# 10            Black            Black, Diane         R        1        1
# 11        Blackburn       Blackburn, Marsha         R        1        1
# 12       Blumenauer        Blumenauer, Earl         D        1        1
# 13         Boustany           Higgins, Clay         R        0        0
# 14            Brady            Brady, Kevin         R        1        1
# 15            Brady              Brady, Bob         D        1        1
# 16           Brooks              Brooks, Mo         R        1        1
# 17            Brown              Lawson, Al         D        1        1
# 18         Buchanan          Buchanan, Vern         R        1        1
# 19          Bucshon          Bucshon, Larry         R        1        1
# 20          Burgess        Burgess, Michael         R        1        1
# 21      Butterfield       Butterfield, G.K.         D        1        1
# 22          Calvert            Calvert, Ken         R        1        1
# 23            Capps         Carbajal, Salud         D        0        0
# 24          Capuano           Capuano, Mike         D        1        1
# 25           Carney   Blunt Rochester, Lisa         D        1        1
# 26           Carson           Carson, Andre         D        1        1
# 27           Carter            Carter, John         R        1        1
# 28           Castor           Castor, Kathy         D        1        1
# 29           Chabot           Chabot, Steve         R        1        1
# ..              ...                     ...       ...      ...      ...
# 405         Ashford              Bacon, Don         R        1        1
# 406       MacArthur          MacArthur, Tom         R        1        1
# 407  Watson Coleman  Watson Coleman, Bonnie         D        1        1
# 408           Hardy           Kihuen, Ruben         D        1        1
# 409          Zeldin             Zeldin, Lee         R        1        1
# 410            Rice          Rice, Kathleen         D        1        1
# 411        Stefanik         Stefanik, Elise         R        1        1
# 412           Katko             Katko, John         R        1        1
# 413         Russell          Russell, Steve         R        1        1
# 414        Costello          Costello, Ryan         R        1        1
# 415           Boyle          Boyle, Brendan         D        1        1
# 416       Ratcliffe         Ratcliffe, John         R        1        1
# 417            Hurd              Hurd, Will         R        1        1
# 418           Babin            Babin, Brian         R        1        1
# 419            Love               Love, Mia         R        1        1
# 420           Beyer              Beyer, Don         D        1        1
# 421        Comstock       Comstock, Barbara         R        1        1
# 422        Newhouse           Newhouse, Dan         R        1        1
# 423        Grothman         Grothman, Glenn         R        1        1
# 424          Mooney            Mooney, Alex         R        1        1
# 425         Jenkins           Jenkins, Evan         R        1        1
# 426          Walker            Walker, Mark         R        1        1
# 427         Donovan            Donovan, Dan         R        1        1
# 428           Kelly            Kelly, Trent         R        1        1
# 429          LaHood           LaHood, Darin         R        1        1
# 430             NaN       Hanabusa, Colleen         D        0        0
# 431             NaN            Comer, James         R        1        1
# 432             NaN        Peterson, Collin         D        1        1
# 433             NaN        Davidson, Warren         R        1        1
# 434             NaN           Evans, Dwight         D        0        0
#
#      had_challenger  winner_votes  runnerup_votes winner_party runnerup_party
# 0                 0      235925.0          3519.0            R       write in
# 1                 1      203545.0        128400.0            R              D
# 2                 1      199421.0        113800.0            R              D
# 3                 1      159444.0        106667.0            R              D
# 4                 1      192490.0         44782.0            D              D
# 5                 1      122842.0         36314.0            D              D
# 6                 0      197777.0        144334.0            R              D
# 7                 1      253559.0        116110.0            R              D
# 8                 1      182925.0         73380.0            R              D
# 9                 1      148543.0         94056.0            D              R
# 10                1      202234.0         61995.0            R              D
# 11                1      200407.0         65226.0            R              D
# 12                1      274687.0         78154.0            D              I
# 13                0       91532.0         84912.0            R              R
# 14                1      236379.0             0.0            R           NONE
# 15                1      245791.0         53219.0            D              R
# 16                1      205647.0        102234.0            R              D
# 17                1      194549.0        108325.0            D              R
# 18                1      230654.0        155262.0            R              D
# 19                1      187702.0         93356.0            R              D
# 20                1      211730.0         94507.0            R              D
# 21                1      240661.0        101567.0            D              R
# 22                1      149547.0        104689.0            R              D
# 23                0      166034.0        144780.0            D              D
# 24                1      253354.0          3557.0            D       Write in
# 25                1      233554.0        172301.0            D              R
# 26                1      158739.0         94456.0            D              R
# 27                1      166060.0        103852.0            R              D
# 28                1      195789.0        121088.0            D              R
# 29                1      210014.0        144644.0            R              D
# ..              ...           ...             ...          ...            ...
# 405               1      141066.0        137602.0            R              D
# 406               1      194596.0        127526.0            R              D
# 407               1      181430.0         92407.0            D              R
# 408               1      128985.0        118328.0            D              R
# 409               1      188499.0        135278.0            R              D
# 410               1      186423.0        126438.0            D              R
# 411               1      177886.0         82161.0            R              D
# 412               1      182761.0        119040.0            R              D
# 413               1      160184.0        103273.0            R              D
# 414               1      207469.0        155000.0            R              D
# 415               0      239316.0             0.0            D           NONE
# 416               1      216643.0         29577.0            R              L
# 417               1      110577.0        107526.0            R              D
# 418               1      193675.0         24890.0            R              G
# 419               1      147597.0        113413.0            R              D
# 420               1      246653.0         98387.0            D              R
# 421               1      210791.0        187712.0            R              D
# 422               1      132517.0         97402.0            R              R
# 423               1      204147.0        133072.0            R              D
# 424               1      140807.0        101207.0            R              D
# 425               1      140741.0         49708.0            R              D
# 426               1      207983.0        143167.0            R              D
# 427               1      142934.0         85257.0            R              D
# 428               1      206455.0         83947.0            R              D
# 429               1      250506.0         96770.0            R              D
# 430               0      145417.0         45958.0            D              R
# 431               1      216959.0         81710.0            R              D
# 432               1      173589.0        156952.0            D              R
# 433               1      223833.0         87794.0            R              D
# 434               0      322514.0         35131.0            D              R
#
# [435 rows x 16 columns]

# %%
# match bioguide id data to name data from Ballotpedia for the Senate
senate_election_and_meta = pd.merge(df_meta, bp_sen, left_on=['state','name.last','district'], right_on=['state','inc_name','district'], how='right')
senate_election_and_meta
# Out:
#    id.bioguide           handle state district type       party   name.last  \
# 0      A000368      kellyayotte    NH     None  sen  Republican      Ayotte
# 1      B001267      senbennetco    CO     None  sen    Democrat      Bennet
# 2      B001277    senblumenthal    CT     None  sen    Democrat  Blumenthal
# 3      B000575         royblunt    MO     None  sen  Republican       Blunt
# 4      B001236      johnboozman    AR     None  sen  Republican     Boozman
# 5      B000711     senatorboxer    CA     None  sen    Democrat       Boxer
# 6      B001135      senatorburr    NC     None  sen  Republican        Burr
# 7      C000880        mikecrapo    ID     None  sen  Republican       Crapo
# 8      G000386    chuckgrassley    IA     None  sen  Republican    Grassley
# 9      H001061    senjohnhoeven    ND     None  sen  Republican      Hoeven
# 10     I000055   senatorisakson    GA     None  sen  Republican     Isakson
# 11     K000360      senatorkirk    IL     None  sen  Republican        Kirk
# 12     L000575  senatorlankford    OK     None  sen  Republican    Lankford
# 13     L000174     senatorleahy    VT     None  sen    Democrat       Leahy
# 14     L000577       senmikelee    UT     None  sen  Republican         Lee
# 15     M000303    senjohnmccain    AZ     None  sen  Republican      McCain
# 16     M000702      senatorbarb    MD     None  sen    Democrat    Mikulski
# 17     M000934       jerrymoran    KS     None  sen  Republican       Moran
# 18     M001153    lisamurkowski    AK     None  sen  Republican   Murkowski
# 19     M001111      pattymurray    WA     None  sen    Democrat      Murray
# 20     P000603              NaN    KY     None  sen  Republican        Paul
# 21     P000449    senrobportman    OH     None  sen  Republican     Portman
# 22     R000146      senatorreid    NV     None  sen    Democrat        Reid
# 23     R000595    senrubiopress    FL     None  sen  Republican       Rubio
# 24     S000148       senschumer    NY     None  sen    Democrat     Schumer
# 25     S001184  senatortimscott    SC     None  sen  Republican       Scott
# 26     S000320        senshelby    AL     None  sen  Republican      Shelby
# 27     T000250     senjohnthune    SD     None  sen  Republican       Thune
# 28     T000461        sentoomey    PA     None  sen  Republican      Toomey
# 29     V000127              NaN    LA     None  sen  Republican      Vitter
# 30     W000779         ronwyden    OR     None  sen    Democrat       Wyden
# 31     S001194   senbrianschatz    HI     None  sen    Democrat      Schatz
# 32         NaN              NaN    IN     None  NaN         NaN         NaN
#
#       inc_name inc_party  inc_ran  inc_won  had_challenger  winner_votes  \
# 0       Ayotte         R        1        0               1        354649
# 1       Bennet         D        1        1               1       1370710
# 2   Blumenthal         D        1        1               1       1008714
# 3        Blunt         R        1        1               1       1378458
# 4      Boozman         R        1        1               1        661984
# 5        Boxer         D        0        0               0       7542753
# 6         Burr         R        1        1               1       2395376
# 7        Crapo         R        1        1               1        449017
# 8     Grassley         R        1        1               1        926007
# 9       Hoeven         R        1        1               1        268788
# 10     Isakson         R        1        1               1       2135806
# 11        Kirk         R        1        0               1       3012940
# 12    Lankford         R        1        1               1        980892
# 13       Leahy         D        1        1               1        192243
# 14         Lee         R        1        1               1        760241
# 15      McCain         R        1        1               1       1359267
# 16    Mikulski         D        0        0               0       1659907
# 17       Moran         R        1        1               1        732376
# 18   Murkowski         R        1        1               1        138149
# 19      Murray         D        1        1               1       1913979
# 20        Paul         R        1        1               1       1090177
# 21     Portman         R        1        1               1       3118567
# 22        Reid         D        0        0               0        521994
# 23       Rubio         R        1        1               1       4835191
# 24     Schumer         D        1        1               1       5221949
# 25       Scott         R        1        1               1       1241609
# 26      Shelby         R        1        1               1       1335104
# 27       Thune         R        1        1               1        265516
# 28      Toomey         R        1        1               1       2951702
# 29      Vitter         R        0        0               0        482591
# 30       Wyden         D        1        1               1       1105119
# 31      Schatz         D        1        1               1        306604
# 32       Pence         R        0        0               0       1423991
#
#     runnerup_votes winner_party runnerup_party
# 0           353632            D              R
# 1          1215318            D              R
# 2           552621            D              R
# 3          1300200            R              D
# 4           400602            R              D
# 5          4701417            D              D
# 6          2128165            R              D
# 7           188249            R              D
# 8           549460            R              D
# 9            58116            R              D
# 10         1599726            R              D
# 11         2184692            D              R
# 12          355911            R              D
# 13          103637            D              R
# 14          301860            R              D
# 15         1031245            R              D
# 16          972557            D              R
# 17          379740            R              D
# 18           36200            R              D
# 19         1329338            D              R
# 20          813246            R              D
# 21         1996908            R              D
# 22          495079            D              R
# 23         4122088            R              D
# 24         2009353            D              R
# 25          757022            R              D
# 26          748709            R              D
# 27          104140            R              D
# 28         2865012            R              D
# 29          337833            R              D
# 30          651106            D              R
# 31           92653            D              R
# 32         1158947            R              D

# %%
# combine house and senate results
election_results = pd.concat([house_election_and_meta, senate_election_and_meta])

# race closeness
election_results['margin'] = (election_results['winner_votes'] - election_results['runnerup_votes'])/(election_results['winner_votes'] + election_results['runnerup_votes'])
election_results.to_csv(git_data_path + 'meta_and_election_results.csv', encoding='utf-8')

election_results
# Out:
#    id.bioguide           handle state district type       party    name.last  \
# 0      A000055  robert_aderholt    AL      4.0  rep  Republican     Aderholt
# 1      A000367              NaN    MI      3.0  rep  Republican        Amash
# 2      B001269   reploubarletta    PA     11.0  rep  Republican     Barletta
# 3      B000213     repjoebarton    TX      6.0  rep  Republican       Barton
# 4      B001270     repkarenbass    CA     37.0  rep    Democrat         Bass
# 5      B000287       repbecerra    CA     34.0  rep    Democrat      Becerra
# 6      B001271   congressmandan    MI      1.0  rep  Republican     Benishek
# 7      B001257  repgusbilirakis    FL     12.0  rep  Republican    Bilirakis
# 8      B001250     reprobbishop    UT      1.0  rep  Republican       Bishop
# 9      B000490    sanfordbishop    GA      2.0  rep    Democrat       Bishop
# 10     B001273    repdianeblack    TN      6.0  rep  Republican        Black
# 11     B001243  marshablackburn    TN      7.0  rep  Republican    Blackburn
# 12     B000574  blumenauermedia    OR      3.0  rep    Democrat   Blumenauer
# 13     B001255      repboustany    LA      3.0  rep  Republican     Boustany
# 14     B000755    repkevinbrady    TX      8.0  rep  Republican        Brady
# 15     B001227         repbrady    PA      1.0  rep    Democrat        Brady
# 16     B001274      repmobrooks    AL      5.0  rep  Republican       Brooks
# 17     B000911  repcorrinebrown    FL      5.0  rep    Democrat        Brown
# 18     B001260     vernbuchanan    FL     16.0  rep  Republican     Buchanan
# 19     B001275  replarrybucshon    IN      8.0  rep  Republican      Bucshon
# 20     B001248  michaelcburgess    TX     26.0  rep  Republican      Burgess
# 21     B001251    gkbutterfield    NC      1.0  rep    Democrat  Butterfield
# 22     C000059       kencalvert    CA     42.0  rep  Republican      Calvert
# 23     C001036     reploiscapps    CA     24.0  rep    Democrat        Capps
# 24     C001037   repmikecapuano    MA      7.0  rep    Democrat      Capuano
# 25     C001083     johncarneyde    DE      0.0  rep    Democrat       Carney
# 26     C001072   repandrecarson    IN      7.0  rep    Democrat       Carson
# 27     C001051      judgecarter    TX     31.0  rep  Republican       Carter
# 28     C001066     usrepkcastor    FL     14.0  rep    Democrat       Castor
# 29     C000266   repstevechabot    OH      1.0  rep  Republican       Chabot
# ..         ...              ...   ...      ...  ...         ...          ...
# 3      B000575         royblunt    MO     None  sen  Republican        Blunt
# 4      B001236      johnboozman    AR     None  sen  Republican      Boozman
# 5      B000711     senatorboxer    CA     None  sen    Democrat        Boxer
# 6      B001135      senatorburr    NC     None  sen  Republican         Burr
# 7      C000880        mikecrapo    ID     None  sen  Republican        Crapo
# 8      G000386    chuckgrassley    IA     None  sen  Republican     Grassley
# 9      H001061    senjohnhoeven    ND     None  sen  Republican       Hoeven
# 10     I000055   senatorisakson    GA     None  sen  Republican      Isakson
# 11     K000360      senatorkirk    IL     None  sen  Republican         Kirk
# 12     L000575  senatorlankford    OK     None  sen  Republican     Lankford
# 13     L000174     senatorleahy    VT     None  sen    Democrat        Leahy
# 14     L000577       senmikelee    UT     None  sen  Republican          Lee
# 15     M000303    senjohnmccain    AZ     None  sen  Republican       McCain
# 16     M000702      senatorbarb    MD     None  sen    Democrat     Mikulski
# 17     M000934       jerrymoran    KS     None  sen  Republican        Moran
# 18     M001153    lisamurkowski    AK     None  sen  Republican    Murkowski
# 19     M001111      pattymurray    WA     None  sen    Democrat       Murray
# 20     P000603              NaN    KY     None  sen  Republican         Paul
# 21     P000449    senrobportman    OH     None  sen  Republican      Portman
# 22     R000146      senatorreid    NV     None  sen    Democrat         Reid
# 23     R000595    senrubiopress    FL     None  sen  Republican        Rubio
# 24     S000148       senschumer    NY     None  sen    Democrat      Schumer
# 25     S001184  senatortimscott    SC     None  sen  Republican        Scott
# 26     S000320        senshelby    AL     None  sen  Republican       Shelby
# 27     T000250     senjohnthune    SD     None  sen  Republican        Thune
# 28     T000461        sentoomey    PA     None  sen  Republican       Toomey
# 29     V000127              NaN    LA     None  sen  Republican       Vitter
# 30     W000779         ronwyden    OR     None  sen    Democrat        Wyden
# 31     S001194   senbrianschatz    HI     None  sen    Democrat       Schatz
# 32         NaN              NaN    IN     None  NaN         NaN          NaN
#
#                  inc_name inc_party  inc_ran  inc_won  had_challenger  \
# 0           Aderholt, Rob         R        1        1               0
# 1           Amash, Justin         R        1        1               1
# 2           Barletta, Lou         R        1        1               1
# 3             Barton, Joe         R        1        1               1
# 4             Bass, Karen         D        1        1               1
# 5         Becerra, Xavier         D        1        1               1
# 6           Bergman, Jack         R        0        0               0
# 7          Bilirakis, Gus         R        1        1               1
# 8             Bishop, Rob         R        1        1               1
# 9         Bishop, Sanford         D        1        1               1
# 10           Black, Diane         R        1        1               1
# 11      Blackburn, Marsha         R        1        1               1
# 12       Blumenauer, Earl         D        1        1               1
# 13          Higgins, Clay         R        0        0               0
# 14           Brady, Kevin         R        1        1               1
# 15             Brady, Bob         D        1        1               1
# 16             Brooks, Mo         R        1        1               1
# 17             Lawson, Al         D        1        1               1
# 18         Buchanan, Vern         R        1        1               1
# 19         Bucshon, Larry         R        1        1               1
# 20       Burgess, Michael         R        1        1               1
# 21      Butterfield, G.K.         D        1        1               1
# 22           Calvert, Ken         R        1        1               1
# 23        Carbajal, Salud         D        0        0               0
# 24          Capuano, Mike         D        1        1               1
# 25  Blunt Rochester, Lisa         D        1        1               1
# 26          Carson, Andre         D        1        1               1
# 27           Carter, John         R        1        1               1
# 28          Castor, Kathy         D        1        1               1
# 29          Chabot, Steve         R        1        1               1
# ..                    ...       ...      ...      ...             ...
# 3                   Blunt         R        1        1               1
# 4                 Boozman         R        1        1               1
# 5                   Boxer         D        0        0               0
# 6                    Burr         R        1        1               1
# 7                   Crapo         R        1        1               1
# 8                Grassley         R        1        1               1
# 9                  Hoeven         R        1        1               1
# 10                Isakson         R        1        1               1
# 11                   Kirk         R        1        0               1
# 12               Lankford         R        1        1               1
# 13                  Leahy         D        1        1               1
# 14                    Lee         R        1        1               1
# 15                 McCain         R        1        1               1
# 16               Mikulski         D        0        0               0
# 17                  Moran         R        1        1               1
# 18              Murkowski         R        1        1               1
# 19                 Murray         D        1        1               1
# 20                   Paul         R        1        1               1
# 21                Portman         R        1        1               1
# 22                   Reid         D        0        0               0
# 23                  Rubio         R        1        1               1
# 24                Schumer         D        1        1               1
# 25                  Scott         R        1        1               1
# 26                 Shelby         R        1        1               1
# 27                  Thune         R        1        1               1
# 28                 Toomey         R        1        1               1
# 29                 Vitter         R        0        0               0
# 30                  Wyden         D        1        1               1
# 31                 Schatz         D        1        1               1
# 32                  Pence         R        0        0               0
#
#     winner_votes  runnerup_votes winner_party runnerup_party    margin
# 0       235925.0          3519.0            R       write in  0.970607
# 1       203545.0        128400.0            R              D  0.226378
# 2       199421.0        113800.0            R              D  0.273357
# 3       159444.0        106667.0            R              D  0.198327
# 4       192490.0         44782.0            D              D  0.622526
# 5       122842.0         36314.0            D              D  0.543668
# 6       197777.0        144334.0            R              D  0.156215
# 7       253559.0        116110.0            R              D  0.371816
# 8       182925.0         73380.0            R              D  0.427401
# 9       148543.0         94056.0            D              R  0.224597
# 10      202234.0         61995.0            R              D  0.530748
# 11      200407.0         65226.0            R              D  0.508901
# 12      274687.0         78154.0            D              I  0.557002
# 13       91532.0         84912.0            R              R  0.037519
# 14      236379.0             0.0            R           NONE  1.000000
# 15      245791.0         53219.0            D              R  0.644032
# 16      205647.0        102234.0            R              D  0.335886
# 17      194549.0        108325.0            D              R  0.284686
# 18      230654.0        155262.0            R              D  0.195359
# 19      187702.0         93356.0            R              D  0.335682
# 20      211730.0         94507.0            R              D  0.382785
# 21      240661.0        101567.0            D              R  0.406437
# 22      149547.0        104689.0            R              D  0.176442
# 23      166034.0        144780.0            D              D  0.068382
# 24      253354.0          3557.0            D       Write in  0.972309
# 25      233554.0        172301.0            D              R  0.150923
# 26      158739.0         94456.0            D              R  0.253887
# 27      166060.0        103852.0            R              D  0.230475
# 28      195789.0        121088.0            D              R  0.235741
# 29      210014.0        144644.0            R              D  0.184318
# ..           ...             ...          ...            ...       ...
# 3      1378458.0       1300200.0            R              D  0.029215
# 4       661984.0        400602.0            R              D  0.245987
# 5      7542753.0       4701417.0            D              D  0.232056
# 6      2395376.0       2128165.0            R              D  0.059071
# 7       449017.0        188249.0            R              D  0.409198
# 8       926007.0        549460.0            R              D  0.255205
# 9       268788.0         58116.0            R              D  0.644446
# 10     2135806.0       1599726.0            R              D  0.143508
# 11     3012940.0       2184692.0            D              R  0.159351
# 12      980892.0        355911.0            R              D  0.467519
# 13      192243.0        103637.0            D              R  0.299466
# 14      760241.0        301860.0            R              D  0.431579
# 15     1359267.0       1031245.0            R              D  0.137218
# 16     1659907.0        972557.0            D              R  0.261105
# 17      732376.0        379740.0            R              D  0.317086
# 18      138149.0         36200.0            R              D  0.584741
# 19     1913979.0       1329338.0            D              R  0.180260
# 20     1090177.0        813246.0            R              D  0.145491
# 21     3118567.0       1996908.0            R              D  0.219268
# 22      521994.0        495079.0            D              R  0.026463
# 23     4835191.0       4122088.0            R              D  0.079612
# 24     5221949.0       2009353.0            D              R  0.444262
# 25     1241609.0        757022.0            R              D  0.242459
# 26     1335104.0        748709.0            R              D  0.281405
# 27      265516.0        104140.0            R              D  0.436557
# 28     2951702.0       2865012.0            R              D  0.014904
# 29      482591.0        337833.0            R              D  0.176443
# 30     1105119.0        651106.0            D              R  0.258516
# 31      306604.0         92653.0            D              R  0.535873
# 32     1423991.0       1158947.0            R              D  0.102613
#
# [468 rows x 17 columns]

# %% [markdown]
# ## Merge Meta + Election Data with Scores data

# %%
# only people who ran for re-election
df_wide = pd.merge(election_results, weekly_df, on='handle', how='left')
df_wide.dropna(subset=['handle'], how='any', inplace=True)
df_wide.to_csv(git_data_path + 'merged_wide.csv', encoding='utf-8')

df_wide
# Out:
#     id.bioguide           handle state district type       party    name.last  \
# 0       A000055  robert_aderholt    AL      4.0  rep  Republican     Aderholt
# 2       B001269   reploubarletta    PA     11.0  rep  Republican     Barletta
# 3       B000213     repjoebarton    TX      6.0  rep  Republican       Barton
# 4       B001270     repkarenbass    CA     37.0  rep    Democrat         Bass
# 5       B000287       repbecerra    CA     34.0  rep    Democrat      Becerra
# 6       B001271   congressmandan    MI      1.0  rep  Republican     Benishek
# 7       B001257  repgusbilirakis    FL     12.0  rep  Republican    Bilirakis
# 8       B001250     reprobbishop    UT      1.0  rep  Republican       Bishop
# 9       B000490    sanfordbishop    GA      2.0  rep    Democrat       Bishop
# 10      B001273    repdianeblack    TN      6.0  rep  Republican        Black
# 11      B001243  marshablackburn    TN      7.0  rep  Republican    Blackburn
# 12      B000574  blumenauermedia    OR      3.0  rep    Democrat   Blumenauer
# 13      B001255      repboustany    LA      3.0  rep  Republican     Boustany
# 14      B000755    repkevinbrady    TX      8.0  rep  Republican        Brady
# 15      B001227         repbrady    PA      1.0  rep    Democrat        Brady
# 16      B001274      repmobrooks    AL      5.0  rep  Republican       Brooks
# 17      B000911  repcorrinebrown    FL      5.0  rep    Democrat        Brown
# 18      B001260     vernbuchanan    FL     16.0  rep  Republican     Buchanan
# 19      B001275  replarrybucshon    IN      8.0  rep  Republican      Bucshon
# 20      B001248  michaelcburgess    TX     26.0  rep  Republican      Burgess
# 21      B001251    gkbutterfield    NC      1.0  rep    Democrat  Butterfield
# 22      C000059       kencalvert    CA     42.0  rep  Republican      Calvert
# 23      C001036     reploiscapps    CA     24.0  rep    Democrat        Capps
# 24      C001037   repmikecapuano    MA      7.0  rep    Democrat      Capuano
# 25      C001083     johncarneyde    DE      0.0  rep    Democrat       Carney
# 26      C001072   repandrecarson    IN      7.0  rep    Democrat       Carson
# 27      C001051      judgecarter    TX     31.0  rep  Republican       Carter
# 28      C001066     usrepkcastor    FL     14.0  rep    Democrat       Castor
# 29      C000266   repstevechabot    OH      1.0  rep  Republican       Chabot
# 30      C001076  jasoninthehouse    UT      3.0  rep  Republican     Chaffetz
# ..          ...              ...   ...      ...  ...         ...          ...
# 435     A000368      kellyayotte    NH     None  sen  Republican       Ayotte
# 436     B001267      senbennetco    CO     None  sen    Democrat       Bennet
# 437     B001277    senblumenthal    CT     None  sen    Democrat   Blumenthal
# 438     B000575         royblunt    MO     None  sen  Republican        Blunt
# 439     B001236      johnboozman    AR     None  sen  Republican      Boozman
# 440     B000711     senatorboxer    CA     None  sen    Democrat        Boxer
# 441     B001135      senatorburr    NC     None  sen  Republican         Burr
# 442     C000880        mikecrapo    ID     None  sen  Republican        Crapo
# 443     G000386    chuckgrassley    IA     None  sen  Republican     Grassley
# 444     H001061    senjohnhoeven    ND     None  sen  Republican       Hoeven
# 445     I000055   senatorisakson    GA     None  sen  Republican      Isakson
# 446     K000360      senatorkirk    IL     None  sen  Republican         Kirk
# 447     L000575  senatorlankford    OK     None  sen  Republican     Lankford
# 448     L000174     senatorleahy    VT     None  sen    Democrat        Leahy
# 449     L000577       senmikelee    UT     None  sen  Republican          Lee
# 450     M000303    senjohnmccain    AZ     None  sen  Republican       McCain
# 451     M000702      senatorbarb    MD     None  sen    Democrat     Mikulski
# 452     M000934       jerrymoran    KS     None  sen  Republican        Moran
# 453     M001153    lisamurkowski    AK     None  sen  Republican    Murkowski
# 454     M001111      pattymurray    WA     None  sen    Democrat       Murray
# 456     P000449    senrobportman    OH     None  sen  Republican      Portman
# 457     R000146      senatorreid    NV     None  sen    Democrat         Reid
# 458     R000595    senrubiopress    FL     None  sen  Republican        Rubio
# 459     S000148       senschumer    NY     None  sen    Democrat      Schumer
# 460     S001184  senatortimscott    SC     None  sen  Republican        Scott
# 461     S000320        senshelby    AL     None  sen  Republican       Shelby
# 462     T000250     senjohnthune    SD     None  sen  Republican        Thune
# 463     T000461        sentoomey    PA     None  sen  Republican       Toomey
# 465     W000779         ronwyden    OR     None  sen    Democrat        Wyden
# 466     S001194   senbrianschatz    HI     None  sen    Democrat       Schatz
#
#                   inc_name inc_party  inc_ran    ...        margin      week1  \
# 0            Aderholt, Rob         R        1    ...      0.970607   1.508142
# 2            Barletta, Lou         R        1    ...      0.273357        NaN
# 3              Barton, Joe         R        1    ...      0.198327   1.933650
# 4              Bass, Karen         D        1    ...      0.622526 -14.938060
# 5          Becerra, Xavier         D        1    ...      0.543668 -30.206601
# 6            Bergman, Jack         R        0    ...      0.156215        NaN
# 7           Bilirakis, Gus         R        1    ...      0.371816   1.312443
# 8              Bishop, Rob         R        1    ...      0.427401        NaN
# 9          Bishop, Sanford         D        1    ...      0.224597  -1.034570
# 10            Black, Diane         R        1    ...      0.530748   2.974408
# 11       Blackburn, Marsha         R        1    ...      0.508901   1.263750
# 12        Blumenauer, Earl         D        1    ...      0.557002        NaN
# 13           Higgins, Clay         R        0    ...      0.037519   1.314222
# 14            Brady, Kevin         R        1    ...      1.000000   7.762922
# 15              Brady, Bob         D        1    ...      0.644032  -1.510763
# 16              Brooks, Mo         R        1    ...      0.335886   3.753665
# 17              Lawson, Al         D        1    ...      0.284686        NaN
# 18          Buchanan, Vern         R        1    ...      0.195359   0.426322
# 19          Bucshon, Larry         R        1    ...      0.335682   4.099385
# 20        Burgess, Michael         R        1    ...      0.382785   3.172264
# 21       Butterfield, G.K.         D        1    ...      0.406437 -31.201828
# 22            Calvert, Ken         R        1    ...      0.176442        NaN
# 23         Carbajal, Salud         D        0    ...      0.068382 -33.196006
# 24           Capuano, Mike         D        1    ...      0.972309        NaN
# 25   Blunt Rochester, Lisa         D        1    ...      0.150923 -40.971865
# 26           Carson, Andre         D        1    ...      0.253887  -0.342110
# 27            Carter, John         R        1    ...      0.230475   2.224507
# 28           Castor, Kathy         D        1    ...      0.235741 -44.156545
# 29           Chabot, Steve         R        1    ...      0.184318   9.609916
# 30         Chaffetz, Jason         R        1    ...      0.469228   2.892066
# ..                     ...       ...      ...    ...           ...        ...
# 435                 Ayotte         R        1    ...      0.001436   2.183923
# 436                 Bennet         D        1    ...      0.060089        NaN
# 437             Blumenthal         D        1    ...      0.292117 -34.844977
# 438                  Blunt         R        1    ...      0.029215   1.293236
# 439                Boozman         R        1    ...      0.245987 -29.542575
# 440                  Boxer         D        0    ...      0.232056        NaN
# 441                   Burr         R        1    ...      0.059071  -4.093707
# 442                  Crapo         R        1    ...      0.409198  -2.966922
# 443               Grassley         R        1    ...      0.255205        NaN
# 444                 Hoeven         R        1    ...      0.644446        NaN
# 445                Isakson         R        1    ...      0.143508   4.105543
# 446                   Kirk         R        1    ...      0.159351   3.650122
# 447               Lankford         R        1    ...      0.467519   0.405730
# 448                  Leahy         D        1    ...      0.299466 -64.294078
# 449                    Lee         R        1    ...      0.431579   2.901310
# 450                 McCain         R        1    ...      0.137218   9.477244
# 451               Mikulski         D        0    ...      0.261105        NaN
# 452                  Moran         R        1    ...      0.317086   1.041650
# 453              Murkowski         R        1    ...      0.584741   2.204160
# 454                 Murray         D        1    ...      0.180260 -30.019642
# 456                Portman         R        1    ...      0.219268   5.189283
# 457                   Reid         D        0    ...      0.026463 -25.980025
# 458                  Rubio         R        1    ...      0.079612 -11.405947
# 459                Schumer         D        1    ...      0.444262 -74.902222
# 460                  Scott         R        1    ...      0.242459   2.240078
# 461                 Shelby         R        1    ...      0.281405   1.691910
# 462                  Thune         R        1    ...      0.436557   5.855200
# 463                 Toomey         R        1    ...      0.014904   0.450846
# 465                  Wyden         D        1    ...      0.258516 -23.538565
# 466                 Schatz         D        1    ...      0.535873 -40.888880
#
#          week2      week3      week4      week5      week6      week7  \
# 0          NaN   2.456140  19.826600        NaN  10.846300        NaN
# 2    -0.114591   3.561290        NaN   0.182323        NaN        NaN
# 3          NaN   2.550000        NaN        NaN   2.173910   2.116500
# 4   -92.063393 -18.224034 -19.090097  -5.101102 -11.509697 -20.173614
# 5   -40.407968 -17.238693  -5.432492  -4.291443  -3.787882  -2.167685
# 6          NaN        NaN        NaN        NaN        NaN        NaN
# 7          NaN        NaN        NaN        NaN        NaN   1.897960
# 8          NaN        NaN        NaN        NaN        NaN        NaN
# 9     0.231907  -1.026090 -49.990600   0.699301        NaN  -0.944954
# 10    3.727599   7.829558   7.146729   2.420896   9.991508   5.292473
# 11    2.044846   0.676640   3.275201   1.040540   1.086960   1.093326
# 12         NaN        NaN        NaN        NaN        NaN        NaN
# 13    0.571769   0.974576   9.514873   4.192653        NaN   1.552931
# 14   18.077057   5.085462   7.298835   9.630764  17.289900  10.460926
# 15         NaN        NaN        NaN  -0.728736  -8.468567 -10.394500
# 16    7.327078   5.725490  13.601200   0.013986        NaN        NaN
# 17         NaN        NaN        NaN        NaN        NaN        NaN
# 18    0.691403   0.570157  -0.001153   0.647187   1.097090   1.097957
# 19    4.488917   2.823553  11.527016   5.906780  12.151820   6.805617
# 20    9.641096   3.910375   6.424018   4.909617   2.539408   5.619437
# 21  -44.965193 -41.815910 -23.698447  -0.944557  -1.013356 -16.951423
# 22         NaN        NaN   8.321410   1.813560  13.165000   6.925530
# 23  -45.494674  -2.384483 -22.353045  -1.000000 -29.509420 -18.358518
# 24         NaN        NaN        NaN        NaN        NaN        NaN
# 25   -7.268290 -10.980400  -0.662230        NaN        NaN        NaN
# 26  -21.588315        NaN -28.224470 -11.564085  -0.969027  -0.896846
# 27    1.819550   8.235118  10.329376   4.175688   0.831308   3.058150
# 28  -44.457523 -45.454540  -6.229427 -30.346366 -27.690219 -17.485778
# 29    3.457630   7.824885  13.051670   6.694487  13.598300   2.624130
# 30    2.476510   9.736850   1.064290        NaN   2.173920   3.957450
# ..         ...        ...        ...        ...        ...        ...
# 435   7.719490   2.974461   4.745522   6.561898   3.111317   3.492292
# 436        NaN        NaN        NaN        NaN        NaN   0.507937
# 437 -11.660406  -3.908745  -3.719649  -3.714757 -14.694660  -2.094742
# 438  10.644147  -0.251815   4.808713   4.538983   6.657333   6.308628
# 439   5.690753   1.952101   3.200514   0.735459   5.767750   2.558430
# 440  -6.368070 -61.565200 -24.810395        NaN -12.873100  -0.857143
# 441  20.187050   2.371015   5.211603   4.297805   5.638980   4.363412
# 442   7.069911   2.289132   2.911630   1.813560   3.977120   2.628961
# 443   0.688525   1.228070   1.193205   0.906780   3.187672   0.983485
# 444   2.333365   0.539624   0.458753   2.450534   2.185408   3.027605
# 445  16.518043   2.068870   5.156220   2.561983   5.995330   1.166670
# 446   2.992400   5.379320   3.882078   2.538492   4.540435   2.691252
# 447   6.569222   4.715713  14.652160   6.435708   4.059387   6.346202
# 448 -48.162200 -28.468984 -17.759672 -14.418847  -7.120868 -16.046247
# 449   5.600755   2.828763   5.701645   9.974580        NaN        NaN
# 450   8.497402   9.703385   9.496810   8.694984   6.750135   5.591056
# 451  -6.193530        NaN        NaN        NaN  -0.911504  -0.865494
# 452  10.568165   2.574680   2.130520   0.961795   5.039773   1.755780
# 453   6.044407   1.908500   4.191600   1.281280        NaN   1.364790
# 454 -33.735608  -4.233609 -13.759030  -8.476360  -8.414560 -14.316002
# 456   6.852277   4.673836   6.820724   6.474956   8.434846   6.211289
# 457        NaN  -2.078500 -25.203463  -2.205610        NaN        NaN
# 458   3.909112  -2.339570   7.003127   9.127218   2.660247   5.548917
# 459 -34.000540  -4.697625 -23.541138  -1.902530  -3.142541  -3.336392
# 460  11.944514  -0.298902   1.634652  11.628269   2.852245   2.430567
# 461   1.030300   2.351350   1.064290   0.569267        NaN        NaN
# 462   1.254841        NaN   3.234770   1.527780   1.097090   2.590910
# 463   1.340321        NaN   1.730260        NaN   5.793066   0.989362
# 465 -35.355218  -6.834717 -21.209182  -0.846154  -8.489650  -2.251524
# 466 -29.666305 -16.083118  -2.513630 -18.155633  -1.633146  -5.878770
#
#          week8      week9
# 0     0.851852        NaN
# 2     0.869231        NaN
# 3    16.993080  21.865500
# 4   -11.338472 -26.374088
# 5    -3.903488 -12.661166
# 6          NaN        NaN
# 7    10.711600        NaN
# 8          NaN        NaN
# 9    -4.695650        NaN
# 10    9.057695   3.280900
# 11    7.043607   1.850913
# 12         NaN        NaN
# 13    0.796748        NaN
# 14   18.283280  10.493809
# 15         NaN        NaN
# 16         NaN   1.336730
# 17         NaN        NaN
# 18    0.838044   0.908607
# 19   10.639210  28.071400
# 20    3.672698  46.319250
# 21  -21.594805 -42.551175
# 22   23.203200   0.969388
# 23  -20.904660 -35.994900
# 24         NaN        NaN
# 25         NaN        NaN
# 26   -1.241885  -2.256520
# 27   10.051637   6.051328
# 28  -39.017744 -32.601153
# 29   14.566276  -0.074886
# 30    6.950120   2.481175
# ..         ...        ...
# 435   2.867487   5.338586
# 436        NaN        NaN
# 437  -9.450100  -3.993935
# 438  15.816653  13.999820
# 439   8.470236   3.563882
# 440        NaN        NaN
# 441   2.062450   7.918155
# 442   0.977778   2.009003
# 443   0.796748   1.163210
# 444   4.512970   2.633680
# 445   1.734671        NaN
# 446   1.175212   2.165448
# 447  15.318518   6.851677
# 448 -12.162636  -5.842507
# 449        NaN   0.439863
# 450  12.636393   8.558045
# 451        NaN -29.175600
# 452   0.584122   1.336730
# 453   0.805326  -1.368150
# 454  -4.374875 -41.893100
# 456   6.831431   7.739056
# 457        NaN -36.656500
# 458  11.294743   5.000630
# 459  -1.398418 -16.323835
# 460   1.524934   0.731537
# 461  11.925900        NaN
# 462  25.065300   1.416897
# 463  19.260000   2.122601
# 465  -2.514915 -10.156392
# 466  -1.803175 -11.228742
#
# [453 rows x 26 columns]

# %%
# melt it so each row is a person x week
df_wide = pd.DataFrame.from_csv(git_data_path + 'merged_wide.csv', sep=",", header=0)
df_long = pd.melt(df_wide, id_vars=['id.bioguide','handle','name.last','type','party','district',
               'inc_ran','inc_won','had_challenger','inc_party','winner_party','runnerup_party',
                'runnerup_votes','winner_votes','margin'],
                value_vars=['week1','week2','week3','week4','week5','week6','week7','week8','week9'],
                var_name='week', value_name='avg_score')
df_long['week'] = df_long['week'].str[-1:]
df_long['abs'] = abs(df_long['avg_score'])

df_long.rename(columns = {'type':'chamber'}, inplace = True)

# make sure we have just two parties
df_long.dropna(subset=['party','abs'], how='any', inplace=True)

df_long.to_csv(git_data_path + 'merged_long.csv', encoding='utf-8')
df_long.head()
# Out:
#   id.bioguide           handle  name.last chamber       party district  \
# 0     A000055  robert_aderholt   Aderholt     rep  Republican      4.0
# 2     B000213     repjoebarton     Barton     rep  Republican      6.0
# 3     B001270     repkarenbass       Bass     rep    Democrat     37.0
# 4     B000287       repbecerra    Becerra     rep    Democrat     34.0
# 6     B001257  repgusbilirakis  Bilirakis     rep  Republican     12.0
#
#    inc_ran  inc_won  had_challenger inc_party winner_party runnerup_party  \
# 0        1        1               0         R            R       write in
# 2        1        1               1         R            R              D
# 3        1        1               1         D            D              D
# 4        1        1               1         D            D              D
# 6        1        1               1         R            R              D
#
#    runnerup_votes  winner_votes    margin week  avg_score        abs
# 0          3519.0      235925.0  0.970607    1   1.508142   1.508142
# 2        106667.0      159444.0  0.198327    1   1.933650   1.933650
# 3         44782.0      192490.0  0.622526    1 -14.938060  14.938060
# 4         36314.0      122842.0  0.543668    1 -30.206601  30.206601
# 6        116110.0      253559.0  0.371816    1   1.312443   1.312443

# %% [markdown]
# # Now move to R for analysis
#
# Run ```~/Documents/git/casmlab/purpletag/2016_election.R```
#
# That R script sends its output to ```2016_election_results.txt```

# %%
results = open('data-files/2016_election_results.txt', 'r')
print(results.read())

# %% [markdown]
# Based on the outlier-excluded linear mixed-effects models, it makes sense to remove RepThompson. The pattern stays the same even with RepThompson in the set though: negative effect for republican and week, positive effect for their interaction. ```lmm5``` is the model-of-best-fit.

# %% [markdown]
# ## Changing the way we score hashtags
#
# What if we score tags for the 63-day period and then score MOCS?
#
# Run the following (on the server) to get new scores:
#
# * purpletag parse -t 63 -d 200
# * purpletag score
# * purpletag score --counts --score-mocs
#
# That first command took a week because the code starts with today and works backwards 200 days, one day at a time. Each day takes over an hour. See Issue #18 about options for changing this behavior.
#
# With the new tag measures, can start the process over. Start at "On Server: Parsing scores to CSV" with a new file name.

# %% [markdown]
# # Getting Tag Data for Paper
#
# We need to know more about the tags people were using to make sense of the regression results. So, let's get some tag data.'

# %%
score_files = build_file_list('/data/purpletag/scores', '*.1.scores')
build_df(score_files, '/data/purpletag/scores_by_date.pkl', 'tag')

# %%
import pandas as pd

df = pd.read_pickle('/data/purpletag/scores_by_date.pkl')
df.head()

# %%
df = weekly_avg(df)
df.head()

# %%
df_tags_weeks = df[['week1','week2','week3','week4','week5','week6','week7','week8','week9']]
df_tags_weeks = df_tags_weeks.dropna(how='all')
df_tags_weeks.head()
len(df_tags_weeks.index) # number of hashtags in our df

# %% [markdown]
# What was happening in week 2 that made Democrats so polarized that week?

# %%
week2 = df_tags_weeks.sort_values(by = 'week2', ascending = True)
week2.head(10)

# %%
week2 = df_tags_weeks.sort_values(by = 'week2', ascending = False)
week2.head(10)

# %%
week9_dems = df_tags_weeks.sort_values(by = 'week9', ascending = True)
week9_dems.head(10)

# %%
week9_reps = df_tags_weeks.sort_values(by = 'week9', ascending = False)
week9_reps.head(10)

# %% [markdown]
# # Go to the JSON for examples

# %%
import json
from datetime import datetime

# print(datetime.now().strftime('%Y-%m-%d %H:%M:%S'))

missing = ['repboustany', 'repcorrinebrown', 'repduckworth', 'repgwengraham', 'repjoeheck', 
           'repjoepitts', 'repkirkpatrick', 'repmattsalmon', 'repmickmulvaney', 'repmikepompeo', 
           'repmiketurner', 'repmurphyfl', 'reprobbishop', 'repsamfarr', 'reptoddyoung', 'senatorsessions', 
           'senatortester', 'sentoomey', 'tiberipress', 'yvetteclarke']

# search JSON for high score tweeters
with open('/data/purpletag/jsons/1478545228.json','r') as f:
    for line in f:
        data = json.loads(line)
#         if (data['user']['screen_name'].lower() == 'replawrence' 
#             or data['user']['screen_name'].lower() == 'repdennyheck'): # most polarized Dems during Week 2
        if (data['user']['screen_name'].lower in missing):
            print(data['user']['screen_name'])
            print(data['created_at'])
            print(data['text'])
                        
# print(datetime.now().strftime('%Y-%m-%d %H:%M:%S')) # takes about 2 min to search the whole thing

# %%
matches = list()

# search JSON for high score tags
with open('/data/purpletag/jsons/1478545228.json','r') as f:
    for line in f:
        data = json.loads(line)
        tags = data['entities']['hashtags']
        for tag in tags:
            if tag['text'].lower() == 'gunvote':
                matches.append(data['id'])
                print(data['user']['screen_name'])
                print(data['created_at'])
                print(data['text'])

print(len(matches))

# %%
# check for missing data from alternate_route.ipynb
# search JSON for high score tags
with open('/data/purpletag/jsons/1478545228.json','r') as f:
    for line in f:
        data = json.loads(line)
        tags = data['entities']['hashtags']
        for tag in tags:
            if tag['text'].lower() == 'gunvote':
                matches.append(data['id'])
                print(data['user']['screen_name'])
                print(data['created_at'])
                print(data['text'])

print(len(matches))
